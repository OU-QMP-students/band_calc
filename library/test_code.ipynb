# %% [markdown]
# ## This Note book is for testing mylibrary:pyfp.

# %%
# import 
from pyfp.convergence import FindData

# %% [markdown]
# #### Test the class; "FindData"
# - path: band_calc/library/pyfp/pyfp.py
# - description:  function to extract energy from the "fplo.out" file triggered by the string "EE"

# %%
filepath = '../research/cerium/CeCoSi/fplo.out'
FindData(filepath).find_energys()
# Out:
#           total energy  kinetic energy potential energy ex.-corr. energy
# 0    -21079.7863326755  22379.29912082  -42894.76388978    -564.32156372
# 1    -21079.7248325915  22379.05620620  -42894.53373530    -564.24730350
# 2    -21078.7314040554  22370.56917816  -42887.30974627    -561.99083595
# 3    -21078.7136694513  22370.95884319  -42888.96664179    -560.70587085
# 4    -21078.5953045229  22378.00791529  -42894.15625550    -562.44696432
# ..                 ...             ...              ...              ...
# 109  -21078.2030241346  22404.19279593  -42920.80017145    -561.59564862
# 110  -21078.2030241566  22404.19278923  -42920.80016478    -561.59564861
# 111  -21078.2030241428  22404.19267873  -42920.80005472    -561.59564815
# 112  -21078.2030242537  22404.19458920  -42920.80194369    -561.59566976
# 113  -21078.2030241451  22404.19461681  -42920.80197769    -561.59566326
#
# [114 rows x 4 columns]

# %%
FindData(filepath).energy_plot()
